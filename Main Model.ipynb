# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from geopy.geocoders import Nominatim
import pickle
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
sample_df = pd.read_csv(r"C:\Users\Abhinav\Desktop\train.csv")

# %%
sample_df.shape
# Out:
# (1458644, 11)

# %%
sample_df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %% [markdown]
# # Data Preprocessing

# %%
sample_df["store_and_fwd_flag"].value_counts()
# Out:
# N    1450599
# Y       8045
# Name: store_and_fwd_flag, dtype: int64

# %%
#Convert character variables to numeric 
f = lambda x: 0 if x == 'N' else 1

sample_df["store_and_fwd_flag"] = sample_df["store_and_fwd_flag"].apply(lambda x: f(x))

# %%
#Check result
sample_df["store_and_fwd_flag"].value_counts()
# Out:
# 0    1450599
# 1       8045
# Name: store_and_fwd_flag, dtype: int64

# %% [markdown]
# # Engineer features

# %%
#First, convert datetime strings into datetime
sample_df["dropoff_datetime"] = pd.to_datetime(sample_df["dropoff_datetime"], format='%Y-%m-%d %H:%M:%S')
sample_df["pickup_datetime"] = pd.to_datetime(sample_df["pickup_datetime"], format='%Y-%m-%d %H:%M:%S')

# %%
#Now construct other variables, like month, date, etc.
sample_df["pickup_month"] = sample_df["pickup_datetime"].dt.month
sample_df["pickup_day"] = sample_df["pickup_datetime"].dt.day
sample_df["pickup_weekday"] = sample_df["pickup_datetime"].dt.weekday #sample_df["pickup_weekday"] = sample_df["pickup_datetime"].dt.weekday_name
sample_df["pickup_hour"] = sample_df["pickup_datetime"].dt.hour
sample_df["pickup_minute"] = sample_df["pickup_datetime"].dt.minute

# %%
#Get latitude and longitude differences 
sample_df["latitude_difference"] = sample_df["dropoff_latitude"] - sample_df["pickup_latitude"]
sample_df["longitude_difference"] = sample_df["dropoff_longitude"] - sample_df["pickup_longitude"]

# %%
#Convert duration to minutes for easier interpretation
sample_df["trip_duration"] = sample_df["trip_duration"].apply(lambda x: round(x/60))

# %%
#Convert trip distance from longitude and latitude differences to Manhattan distance.
sample_df["trip_distance"] = 0.621371 * 6371 * (abs(2 * np.arctan2(np.sqrt(np.square(np.sin((abs(sample_df["latitude_difference"]) * np.pi / 180) / 2))), 
                                  np.sqrt(1-(np.square(np.sin((abs(sample_df["latitude_difference"]) * np.pi / 180) / 2)))))) + \
                                     abs(2 * np.arctan2(np.sqrt(np.square(np.sin((abs(sample_df["longitude_difference"]) * np.pi / 180) / 2))), 
                                  np.sqrt(1-(np.square(np.sin((abs(sample_df["longitude_difference"]) * np.pi / 180) / 2)))))))

# %%
sample_df.head(5)
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude  store_and_fwd_flag  trip_duration  pickup_month  \
# 0         40.765602                   0              8             3
# 1         40.731152                   0             11             6
# 2         40.710087                   0             35             1
# 3         40.706718                   0              7             4
# 4         40.782520                   0              7             3
#
#    pickup_day  pickup_weekday  pickup_hour  pickup_minute  \
# 0          14               0           17             24
# 1          12               6            0             43
# 2          19               1           11             35
# 3           6               2           19             32
# 4          26               5           13             30
#
#    latitude_difference  longitude_difference  trip_distance
# 0            -0.002335              0.017525       1.372146
# 1            -0.007412             -0.019066       1.829440
# 2            -0.053852             -0.026306       5.538397
# 3            -0.013252             -0.002228       1.069567
# 4            -0.010689              0.000130       0.747485

# %% [markdown]
# # Modelling

# %%
X = sample_df.drop(["trip_duration", "id", "vendor_id", "pickup_datetime", "dropoff_datetime"], axis=1)
y = sample_df["trip_duration"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2018)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=2019)

# %%
#Define evaluation metric
def rmsle(y_true, y_pred):
    assert len(y_true) == len(y_pred)
    return np.square(np.log(y_pred + 1) - np.log(y_true + 1)).mean() ** 0.5

# %%
#XGBoost parameters 
params = {
    'booster':            'gbtree',
    'objective':          'reg:linear',
    'learning_rate':      0.05,
    'max_depth':          14,
    'subsample':          0.9,
    'colsample_bytree':   0.7,
    'colsample_bylevel':  0.7,
    'silent':             1,
    'feval':              'rmsle'
}

# %%
nrounds = 2000

# %%
#Define train and validation sets
dtrain = xgb.DMatrix(X_train, np.log(y_train+1))
dval = xgb.DMatrix(X_val, np.log(y_val+1))

#this is for tracking the error
watchlist = [(dval, 'eval'), (dtrain, 'train')]

# %%
#Train model
gbm = xgb.train(params,
                dtrain,
                num_boost_round = nrounds,
                evals = watchlist,
                verbose_eval = True
                )
# Out:
# [01:38:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# [01:38:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { feval, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	eval-rmse:2.00600	train-rmse:2.00533
# [1]	eval-rmse:1.90977	train-rmse:1.90919
# [2]	eval-rmse:1.81870	train-rmse:1.81809
# [3]	eval-rmse:1.73243	train-rmse:1.73183
# [4]	eval-rmse:1.65036	train-rmse:1.64983
# [5]	eval-rmse:1.57251	train-rmse:1.57196
# [6]	eval-rmse:1.49885	train-rmse:1.49826
# [7]	eval-rmse:1.42934	train-rmse:1.42875
# [8]	eval-rmse:1.36316	train-rmse:1.36246
# [9]	eval-rmse:1.30042	train-rmse:1.29947
# [10]	eval-rmse:1.24151	train-rmse:1.24039
# [11]	eval-rmse:1.18619	train-rmse:1.18496
# [12]	eval-rmse:1.13395	train-rmse:1.13259
# [13]	eval-rmse:1.08366	train-rmse:1.08198
# [14]	eval-rmse:1.03616	train-rmse:1.03430
# [15]	eval-rmse:0.99153	train-rmse:0.98946
# [16]	eval-rmse:0.94900	train-rmse:0.94675
# [17]	eval-rmse:0.90897	train-rmse:0.90626
# [18]	eval-rmse:0.87147	train-rmse:0.86853
# [19]	eval-rmse:0.83576	train-rmse:0.83231
# [20]	eval-rmse:0.80236	train-rmse:0.79849
# [21]	eval-rmse:0.77080	train-rmse:0.76659
# [22]	eval-rmse:0.74104	train-rmse:0.73638
# [23]	eval-rmse:0.71321	train-rmse:0.70788
# [24]	eval-rmse:0.68703	train-rmse:0.68095
# [25]	eval-rmse:0.66258	train-rmse:0.65589
# [26]	eval-rmse:0.63972	train-rmse:0.63230
# [27]	eval-rmse:0.61843	train-rmse:0.61027
# [28]	eval-rmse:0.59845	train-rmse:0.58945
# [29]	eval-rmse:0.57942	train-rmse:0.56964
# [30]	eval-rmse:0.56183	train-rmse:0.55106
# [31]	eval-rmse:0.54585	train-rmse:0.53440
# [32]	eval-rmse:0.53134	train-rmse:0.51917
# [33]	eval-rmse:0.51684	train-rmse:0.50366
# [34]	eval-rmse:0.50380	train-rmse:0.48950
# [35]	eval-rmse:0.49163	train-rmse:0.47623
# [36]	eval-rmse:0.48036	train-rmse:0.46421
# [37]	eval-rmse:0.46981	train-rmse:0.45254
# [38]	eval-rmse:0.46015	train-rmse:0.44196
# [39]	eval-rmse:0.45115	train-rmse:0.43192
# [40]	eval-rmse:0.44284	train-rmse:0.42269
# [41]	eval-rmse:0.43479	train-rmse:0.41349
# [42]	eval-rmse:0.42748	train-rmse:0.40505
# [43]	eval-rmse:0.42125	train-rmse:0.39790
# [44]	eval-rmse:0.41489	train-rmse:0.39041
# [45]	eval-rmse:0.40897	train-rmse:0.38363
# [46]	eval-rmse:0.40382	train-rmse:0.37757
# [47]	eval-rmse:0.39884	train-rmse:0.37131
# [48]	eval-rmse:0.39447	train-rmse:0.36575
# [49]	eval-rmse:0.39050	train-rmse:0.36084
# [50]	eval-rmse:0.38655	train-rmse:0.35604
# [51]	eval-rmse:0.38287	train-rmse:0.35122
# [52]	eval-rmse:0.37953	train-rmse:0.34674
# [53]	eval-rmse:0.37660	train-rmse:0.34294
# [54]	eval-rmse:0.37401	train-rmse:0.33953
# [55]	eval-rmse:0.37154	train-rmse:0.33604
# [56]	eval-rmse:0.36904	train-rmse:0.33253
# [57]	eval-rmse:0.36685	train-rmse:0.32947
# [58]	eval-rmse:0.36481	train-rmse:0.32660
# [59]	eval-rmse:0.36295	train-rmse:0.32386
# [60]	eval-rmse:0.36124	train-rmse:0.32122
# [61]	eval-rmse:0.35966	train-rmse:0.31890
# [62]	eval-rmse:0.35831	train-rmse:0.31674
# [63]	eval-rmse:0.35697	train-rmse:0.31467
# [64]	eval-rmse:0.35577	train-rmse:0.31256
# [65]	eval-rmse:0.35452	train-rmse:0.31007
# [66]	eval-rmse:0.35347	train-rmse:0.30804
# [67]	eval-rmse:0.35240	train-rmse:0.30601
# [68]	eval-rmse:0.35138	train-rmse:0.30435
# [69]	eval-rmse:0.35055	train-rmse:0.30262
# [70]	eval-rmse:0.34978	train-rmse:0.30123
# [71]	eval-rmse:0.34900	train-rmse:0.29985
# [72]	eval-rmse:0.34825	train-rmse:0.29828
# [73]	eval-rmse:0.34764	train-rmse:0.29706
# [74]	eval-rmse:0.34712	train-rmse:0.29591
# [75]	eval-rmse:0.34666	train-rmse:0.29485
# [76]	eval-rmse:0.34610	train-rmse:0.29337
# [77]	eval-rmse:0.34558	train-rmse:0.29224
# [78]	eval-rmse:0.34512	train-rmse:0.29085
# [79]	eval-rmse:0.34462	train-rmse:0.28970
# [80]	eval-rmse:0.34421	train-rmse:0.28875
# [81]	eval-rmse:0.34380	train-rmse:0.28755
# [82]	eval-rmse:0.34347	train-rmse:0.28660
# [83]	eval-rmse:0.34313	train-rmse:0.28568
# [84]	eval-rmse:0.34282	train-rmse:0.28490
# [85]	eval-rmse:0.34254	train-rmse:0.28382
# [86]	eval-rmse:0.34221	train-rmse:0.28270
# [87]	eval-rmse:0.34194	train-rmse:0.28182
# [88]	eval-rmse:0.34162	train-rmse:0.28057
# [89]	eval-rmse:0.34137	train-rmse:0.27984
# [90]	eval-rmse:0.34110	train-rmse:0.27892
# [91]	eval-rmse:0.34087	train-rmse:0.27798
# [92]	eval-rmse:0.34059	train-rmse:0.27699
# [93]	eval-rmse:0.34042	train-rmse:0.27608
# [94]	eval-rmse:0.34011	train-rmse:0.27518
# [95]	eval-rmse:0.33985	train-rmse:0.27399
# [96]	eval-rmse:0.33970	train-rmse:0.27314
# [97]	eval-rmse:0.33949	train-rmse:0.27220
# [98]	eval-rmse:0.33932	train-rmse:0.27150
# [99]	eval-rmse:0.33922	train-rmse:0.27083
# [100]	eval-rmse:0.33906	train-rmse:0.27010
# [101]	eval-rmse:0.33881	train-rmse:0.26908
# [102]	eval-rmse:0.33869	train-rmse:0.26841
# [103]	eval-rmse:0.33851	train-rmse:0.26757
# [104]	eval-rmse:0.33847	train-rmse:0.26685
# [105]	eval-rmse:0.33830	train-rmse:0.26617
# [106]	eval-rmse:0.33814	train-rmse:0.26525
# [107]	eval-rmse:0.33791	train-rmse:0.26447
# [108]	eval-rmse:0.33783	train-rmse:0.26379
# [109]	eval-rmse:0.33775	train-rmse:0.26310
# [110]	eval-rmse:0.33758	train-rmse:0.26217
# [111]	eval-rmse:0.33747	train-rmse:0.26155
# [112]	eval-rmse:0.33739	train-rmse:0.26112
# [113]	eval-rmse:0.33726	train-rmse:0.26049
# [114]	eval-rmse:0.33715	train-rmse:0.25966
# [115]	eval-rmse:0.33698	train-rmse:0.25876
# [116]	eval-rmse:0.33689	train-rmse:0.25824
# [117]	eval-rmse:0.33679	train-rmse:0.25757
# [118]	eval-rmse:0.33666	train-rmse:0.25694
# [119]	eval-rmse:0.33659	train-rmse:0.25630
# [120]	eval-rmse:0.33656	train-rmse:0.25577
# [121]	eval-rmse:0.33641	train-rmse:0.25499
# [122]	eval-rmse:0.33627	train-rmse:0.25449
# [123]	eval-rmse:0.33617	train-rmse:0.25378
# [124]	eval-rmse:0.33612	train-rmse:0.25323
# [125]	eval-rmse:0.33607	train-rmse:0.25254
# [126]	eval-rmse:0.33596	train-rmse:0.25199
# [127]	eval-rmse:0.33589	train-rmse:0.25138
# [128]	eval-rmse:0.33577	train-rmse:0.25078
# [129]	eval-rmse:0.33561	train-rmse:0.25014
# [130]	eval-rmse:0.33546	train-rmse:0.24936
# [131]	eval-rmse:0.33534	train-rmse:0.24879
# [132]	eval-rmse:0.33526	train-rmse:0.24827
# [133]	eval-rmse:0.33526	train-rmse:0.24803
# [134]	eval-rmse:0.33516	train-rmse:0.24760
# [135]	eval-rmse:0.33512	train-rmse:0.24726
# [136]	eval-rmse:0.33498	train-rmse:0.24665
# [137]	eval-rmse:0.33495	train-rmse:0.24628
# [138]	eval-rmse:0.33495	train-rmse:0.24593
# [139]	eval-rmse:0.33475	train-rmse:0.24503
# [140]	eval-rmse:0.33469	train-rmse:0.24449
# [141]	eval-rmse:0.33458	train-rmse:0.24396
# [142]	eval-rmse:0.33457	train-rmse:0.24349
# [143]	eval-rmse:0.33455	train-rmse:0.24314
# [144]	eval-rmse:0.33448	train-rmse:0.24256
# [145]	eval-rmse:0.33444	train-rmse:0.24204
# [146]	eval-rmse:0.33440	train-rmse:0.24166
# [147]	eval-rmse:0.33428	train-rmse:0.24100
# [148]	eval-rmse:0.33421	train-rmse:0.24042
# [149]	eval-rmse:0.33416	train-rmse:0.24000
# [150]	eval-rmse:0.33412	train-rmse:0.23972
# [151]	eval-rmse:0.33400	train-rmse:0.23905
# [152]	eval-rmse:0.33398	train-rmse:0.23881
# [153]	eval-rmse:0.33390	train-rmse:0.23813
# [154]	eval-rmse:0.33387	train-rmse:0.23772
# [155]	eval-rmse:0.33381	train-rmse:0.23732
# [156]	eval-rmse:0.33378	train-rmse:0.23721
# [157]	eval-rmse:0.33372	train-rmse:0.23672
# [158]	eval-rmse:0.33371	train-rmse:0.23644
# [159]	eval-rmse:0.33363	train-rmse:0.23584
# [160]	eval-rmse:0.33358	train-rmse:0.23555
# [161]	eval-rmse:0.33352	train-rmse:0.23500
# [162]	eval-rmse:0.33348	train-rmse:0.23457
# [163]	eval-rmse:0.33338	train-rmse:0.23408
# [164]	eval-rmse:0.33326	train-rmse:0.23348
# [165]	eval-rmse:0.33322	train-rmse:0.23321
# [166]	eval-rmse:0.33318	train-rmse:0.23279
# [167]	eval-rmse:0.33315	train-rmse:0.23239
# [168]	eval-rmse:0.33311	train-rmse:0.23178
# [169]	eval-rmse:0.33308	train-rmse:0.23137
# [170]	eval-rmse:0.33304	train-rmse:0.23109
# [171]	eval-rmse:0.33298	train-rmse:0.23061
# [172]	eval-rmse:0.33291	train-rmse:0.23012
# [173]	eval-rmse:0.33283	train-rmse:0.22955
# [174]	eval-rmse:0.33282	train-rmse:0.22945
# [175]	eval-rmse:0.33275	train-rmse:0.22885
# [176]	eval-rmse:0.33268	train-rmse:0.22845
# [177]	eval-rmse:0.33266	train-rmse:0.22815
# [178]	eval-rmse:0.33263	train-rmse:0.22788
# [179]	eval-rmse:0.33261	train-rmse:0.22747
# [180]	eval-rmse:0.33259	train-rmse:0.22722
# [181]	eval-rmse:0.33258	train-rmse:0.22711
# [182]	eval-rmse:0.33254	train-rmse:0.22686
# [183]	eval-rmse:0.33252	train-rmse:0.22651
# [184]	eval-rmse:0.33251	train-rmse:0.22618
# [185]	eval-rmse:0.33249	train-rmse:0.22576
# [186]	eval-rmse:0.33243	train-rmse:0.22523
# [187]	eval-rmse:0.33244	train-rmse:0.22503
# [188]	eval-rmse:0.33244	train-rmse:0.22491
# [189]	eval-rmse:0.33238	train-rmse:0.22460
# [190]	eval-rmse:0.33237	train-rmse:0.22428
# [191]	eval-rmse:0.33235	train-rmse:0.22421
# [192]	eval-rmse:0.33233	train-rmse:0.22384
# [193]	eval-rmse:0.33227	train-rmse:0.22362
# [194]	eval-rmse:0.33226	train-rmse:0.22323
# [195]	eval-rmse:0.33224	train-rmse:0.22317
# [196]	eval-rmse:0.33217	train-rmse:0.22286
# [197]	eval-rmse:0.33203	train-rmse:0.22229
# [198]	eval-rmse:0.33200	train-rmse:0.22209
# [199]	eval-rmse:0.33200	train-rmse:0.22199
# [200]	eval-rmse:0.33188	train-rmse:0.22136
# [201]	eval-rmse:0.33185	train-rmse:0.22102
# [202]	eval-rmse:0.33171	train-rmse:0.22057
# [203]	eval-rmse:0.33169	train-rmse:0.22032
# [204]	eval-rmse:0.33166	train-rmse:0.22006
# [205]	eval-rmse:0.33165	train-rmse:0.21970
# [206]	eval-rmse:0.33164	train-rmse:0.21965
# [207]	eval-rmse:0.33162	train-rmse:0.21938
# [208]	eval-rmse:0.33160	train-rmse:0.21920
# [209]	eval-rmse:0.33151	train-rmse:0.21870
# [210]	eval-rmse:0.33147	train-rmse:0.21844
# [211]	eval-rmse:0.33146	train-rmse:0.21828
# [212]	eval-rmse:0.33145	train-rmse:0.21822
# [213]	eval-rmse:0.33138	train-rmse:0.21794
# [214]	eval-rmse:0.33137	train-rmse:0.21772
# [215]	eval-rmse:0.33131	train-rmse:0.21741
# [216]	eval-rmse:0.33131	train-rmse:0.21727
# [217]	eval-rmse:0.33126	train-rmse:0.21685
# [218]	eval-rmse:0.33114	train-rmse:0.21623
# [219]	eval-rmse:0.33107	train-rmse:0.21574
# [220]	eval-rmse:0.33106	train-rmse:0.21569
# [221]	eval-rmse:0.33105	train-rmse:0.21563
# [222]	eval-rmse:0.33100	train-rmse:0.21527
# [223]	eval-rmse:0.33099	train-rmse:0.21498
# [224]	eval-rmse:0.33097	train-rmse:0.21457
# [225]	eval-rmse:0.33094	train-rmse:0.21440
# [226]	eval-rmse:0.33092	train-rmse:0.21430
# [227]	eval-rmse:0.33092	train-rmse:0.21403
# [228]	eval-rmse:0.33088	train-rmse:0.21363
# [229]	eval-rmse:0.33088	train-rmse:0.21353
# [230]	eval-rmse:0.33088	train-rmse:0.21342
# [231]	eval-rmse:0.33087	train-rmse:0.21330
# [232]	eval-rmse:0.33087	train-rmse:0.21323
# [233]	eval-rmse:0.33084	train-rmse:0.21277
# [234]	eval-rmse:0.33081	train-rmse:0.21241
# [235]	eval-rmse:0.33081	train-rmse:0.21235
# [236]	eval-rmse:0.33075	train-rmse:0.21189
# [237]	eval-rmse:0.33069	train-rmse:0.21165
# [238]	eval-rmse:0.33063	train-rmse:0.21130
# [239]	eval-rmse:0.33060	train-rmse:0.21090
# [240]	eval-rmse:0.33059	train-rmse:0.21084
# [241]	eval-rmse:0.33056	train-rmse:0.21043
# [242]	eval-rmse:0.33055	train-rmse:0.21026
# [243]	eval-rmse:0.33054	train-rmse:0.21001
# [244]	eval-rmse:0.33053	train-rmse:0.20986
# [245]	eval-rmse:0.33049	train-rmse:0.20960
# [246]	eval-rmse:0.33047	train-rmse:0.20942
# [247]	eval-rmse:0.33046	train-rmse:0.20927
# [248]	eval-rmse:0.33045	train-rmse:0.20916
# [249]	eval-rmse:0.33042	train-rmse:0.20888
# [250]	eval-rmse:0.33039	train-rmse:0.20864
# [251]	eval-rmse:0.33037	train-rmse:0.20852
# [252]	eval-rmse:0.33037	train-rmse:0.20822
# [253]	eval-rmse:0.33036	train-rmse:0.20807
# [254]	eval-rmse:0.33036	train-rmse:0.20789
# [255]	eval-rmse:0.33035	train-rmse:0.20785
# [256]	eval-rmse:0.33035	train-rmse:0.20780
# [257]	eval-rmse:0.33027	train-rmse:0.20736
# [258]	eval-rmse:0.33022	train-rmse:0.20697
# [259]	eval-rmse:0.33021	train-rmse:0.20689
# [260]	eval-rmse:0.33021	train-rmse:0.20682
# [261]	eval-rmse:0.33020	train-rmse:0.20672
# [262]	eval-rmse:0.33020	train-rmse:0.20659
# [263]	eval-rmse:0.33016	train-rmse:0.20633
# [264]	eval-rmse:0.33015	train-rmse:0.20620
# [265]	eval-rmse:0.33014	train-rmse:0.20605
# [266]	eval-rmse:0.33013	train-rmse:0.20594
# [267]	eval-rmse:0.33013	train-rmse:0.20583
# [268]	eval-rmse:0.33013	train-rmse:0.20576
# [269]	eval-rmse:0.33011	train-rmse:0.20563
# [270]	eval-rmse:0.33011	train-rmse:0.20549
# [271]	eval-rmse:0.33011	train-rmse:0.20537
# [272]	eval-rmse:0.33011	train-rmse:0.20526
# [273]	eval-rmse:0.33009	train-rmse:0.20508
# [274]	eval-rmse:0.33005	train-rmse:0.20485
# [275]	eval-rmse:0.33006	train-rmse:0.20480
# [276]	eval-rmse:0.33000	train-rmse:0.20454
# [277]	eval-rmse:0.33000	train-rmse:0.20450
# [278]	eval-rmse:0.32998	train-rmse:0.20424
# [279]	eval-rmse:0.32998	train-rmse:0.20421
# [280]	eval-rmse:0.32997	train-rmse:0.20407
# [281]	eval-rmse:0.32997	train-rmse:0.20405
# [282]	eval-rmse:0.32996	train-rmse:0.20391
# [283]	eval-rmse:0.32996	train-rmse:0.20379
# [284]	eval-rmse:0.32995	train-rmse:0.20349
# [285]	eval-rmse:0.32993	train-rmse:0.20318
# [286]	eval-rmse:0.32990	train-rmse:0.20294
# [287]	eval-rmse:0.32989	train-rmse:0.20278
# [288]	eval-rmse:0.32989	train-rmse:0.20273
# [289]	eval-rmse:0.32988	train-rmse:0.20265
# [290]	eval-rmse:0.32987	train-rmse:0.20245
# [291]	eval-rmse:0.32985	train-rmse:0.20216
# [292]	eval-rmse:0.32985	train-rmse:0.20199
# [293]	eval-rmse:0.32982	train-rmse:0.20155
# [294]	eval-rmse:0.32983	train-rmse:0.20153
# [295]	eval-rmse:0.32982	train-rmse:0.20145
# [296]	eval-rmse:0.32980	train-rmse:0.20126
# [297]	eval-rmse:0.32980	train-rmse:0.20119
# [298]	eval-rmse:0.32980	train-rmse:0.20104
# [299]	eval-rmse:0.32979	train-rmse:0.20095
# [300]	eval-rmse:0.32976	train-rmse:0.20075
# [301]	eval-rmse:0.32973	train-rmse:0.20054
# [302]	eval-rmse:0.32972	train-rmse:0.20047
# [303]	eval-rmse:0.32972	train-rmse:0.20035
# [304]	eval-rmse:0.32970	train-rmse:0.20018
# [305]	eval-rmse:0.32970	train-rmse:0.20000
# [306]	eval-rmse:0.32970	train-rmse:0.19984
# [307]	eval-rmse:0.32969	train-rmse:0.19979
# [308]	eval-rmse:0.32967	train-rmse:0.19947
# [309]	eval-rmse:0.32967	train-rmse:0.19931
# [310]	eval-rmse:0.32967	train-rmse:0.19921
# [311]	eval-rmse:0.32964	train-rmse:0.19898
# [312]	eval-rmse:0.32964	train-rmse:0.19890
# [313]	eval-rmse:0.32962	train-rmse:0.19860
# [314]	eval-rmse:0.32962	train-rmse:0.19844
# [315]	eval-rmse:0.32959	train-rmse:0.19821
# [316]	eval-rmse:0.32958	train-rmse:0.19807
# [317]	eval-rmse:0.32955	train-rmse:0.19786
# [318]	eval-rmse:0.32954	train-rmse:0.19769
# [319]	eval-rmse:0.32955	train-rmse:0.19740
# [320]	eval-rmse:0.32955	train-rmse:0.19737
# [376]	eval-rmse:0.32915	train-rmse:0.18989
# [377]	eval-rmse:0.32915	train-rmse:0.18987
# [378]	eval-rmse:0.32913	train-rmse:0.18960
# [379]	eval-rmse:0.32912	train-rmse:0.18946
# [380]	eval-rmse:0.32911	train-rmse:0.18917
# [381]	eval-rmse:0.32910	train-rmse:0.18901
# [382]	eval-rmse:0.32909	train-rmse:0.18872
# [383]	eval-rmse:0.32908	train-rmse:0.18847
# [384]	eval-rmse:0.32908	train-rmse:0.18837
# [385]	eval-rmse:0.32908	train-rmse:0.18833
# [386]	eval-rmse:0.32908	train-rmse:0.18827
# [387]	eval-rmse:0.32904	train-rmse:0.18806
# [388]	eval-rmse:0.32903	train-rmse:0.18802
# [389]	eval-rmse:0.32903	train-rmse:0.18800
# [390]	eval-rmse:0.32903	train-rmse:0.18780
# [391]	eval-rmse:0.32903	train-rmse:0.18765
# [392]	eval-rmse:0.32902	train-rmse:0.18747
# [393]	eval-rmse:0.32902	train-rmse:0.18732
# [394]	eval-rmse:0.32902	train-rmse:0.18723
# [395]	eval-rmse:0.32902	train-rmse:0.18707
# [396]	eval-rmse:0.32902	train-rmse:0.18701
# [397]	eval-rmse:0.32900	train-rmse:0.18686
# [398]	eval-rmse:0.32901	train-rmse:0.18668
# [399]	eval-rmse:0.32900	train-rmse:0.18657
# [400]	eval-rmse:0.32900	train-rmse:0.18655
# [401]	eval-rmse:0.32899	train-rmse:0.18649
# [402]	eval-rmse:0.32899	train-rmse:0.18636
# [403]	eval-rmse:0.32899	train-rmse:0.18624
# [404]	eval-rmse:0.32898	train-rmse:0.18603
# [405]	eval-rmse:0.32898	train-rmse:0.18599
# [406]	eval-rmse:0.32895	train-rmse:0.18579
# [407]	eval-rmse:0.32891	train-rmse:0.18545
# [408]	eval-rmse:0.32891	train-rmse:0.18528
# [409]	eval-rmse:0.32891	train-rmse:0.18526
# [410]	eval-rmse:0.32890	train-rmse:0.18511
# [411]	eval-rmse:0.32890	train-rmse:0.18503
# [412]	eval-rmse:0.32890	train-rmse:0.18488
# [413]	eval-rmse:0.32889	train-rmse:0.18478
# [414]	eval-rmse:0.32889	train-rmse:0.18473
# [415]	eval-rmse:0.32889	train-rmse:0.18460
# [416]	eval-rmse:0.32889	train-rmse:0.18457
# [417]	eval-rmse:0.32889	train-rmse:0.18448
# [418]	eval-rmse:0.32889	train-rmse:0.18440
# [419]	eval-rmse:0.32889	train-rmse:0.18421
# [420]	eval-rmse:0.32889	train-rmse:0.18416
# [421]	eval-rmse:0.32889	train-rmse:0.18413
# [422]	eval-rmse:0.32888	train-rmse:0.18390
# [423]	eval-rmse:0.32887	train-rmse:0.18373
# [424]	eval-rmse:0.32886	train-rmse:0.18349
# [425]	eval-rmse:0.32886	train-rmse:0.18324
# [426]	eval-rmse:0.32886	train-rmse:0.18317
# [427]	eval-rmse:0.32887	train-rmse:0.18307
# [428]	eval-rmse:0.32886	train-rmse:0.18298
# [429]	eval-rmse:0.32886	train-rmse:0.18285
# [430]	eval-rmse:0.32886	train-rmse:0.18267
# [431]	eval-rmse:0.32885	train-rmse:0.18264
# [432]	eval-rmse:0.32885	train-rmse:0.18258
# [433]	eval-rmse:0.32884	train-rmse:0.18243
# [434]	eval-rmse:0.32883	train-rmse:0.18235
# [435]	eval-rmse:0.32883	train-rmse:0.18231
# [436]	eval-rmse:0.32880	train-rmse:0.18216
# [437]	eval-rmse:0.32880	train-rmse:0.18211
# [438]	eval-rmse:0.32879	train-rmse:0.18199
# [439]	eval-rmse:0.32879	train-rmse:0.18187
# [440]	eval-rmse:0.32878	train-rmse:0.18169
# [441]	eval-rmse:0.32878	train-rmse:0.18162
# [442]	eval-rmse:0.32877	train-rmse:0.18154
# [443]	eval-rmse:0.32877	train-rmse:0.18145
# [444]	eval-rmse:0.32876	train-rmse:0.18118
# [445]	eval-rmse:0.32875	train-rmse:0.18090
# [446]	eval-rmse:0.32875	train-rmse:0.18081
# [447]	eval-rmse:0.32874	train-rmse:0.18064
# [448]	eval-rmse:0.32873	train-rmse:0.18058
# [449]	eval-rmse:0.32871	train-rmse:0.18043
# [450]	eval-rmse:0.32871	train-rmse:0.18033
# [451]	eval-rmse:0.32869	train-rmse:0.18019
# [452]	eval-rmse:0.32869	train-rmse:0.18017
# [453]	eval-rmse:0.32869	train-rmse:0.18003
# [454]	eval-rmse:0.32869	train-rmse:0.17997
# [455]	eval-rmse:0.32869	train-rmse:0.17992
# [456]	eval-rmse:0.32869	train-rmse:0.17991
# [457]	eval-rmse:0.32868	train-rmse:0.17966
# [458]	eval-rmse:0.32868	train-rmse:0.17961
# [459]	eval-rmse:0.32868	train-rmse:0.17957
# [460]	eval-rmse:0.32868	train-rmse:0.17954
# [461]	eval-rmse:0.32868	train-rmse:0.17939
# [462]	eval-rmse:0.32867	train-rmse:0.17924
# [463]	eval-rmse:0.32867	train-rmse:0.17913
# [464]	eval-rmse:0.32867	train-rmse:0.17908
# [465]	eval-rmse:0.32866	train-rmse:0.17903
# [466]	eval-rmse:0.32865	train-rmse:0.17892
# [467]	eval-rmse:0.32865	train-rmse:0.17882
# [468]	eval-rmse:0.32865	train-rmse:0.17871
# [469]	eval-rmse:0.32863	train-rmse:0.17855
# [470]	eval-rmse:0.32863	train-rmse:0.17846
# [471]	eval-rmse:0.32861	train-rmse:0.17827
# [472]	eval-rmse:0.32861	train-rmse:0.17821
# [473]	eval-rmse:0.32858	train-rmse:0.17784
# [474]	eval-rmse:0.32859	train-rmse:0.17781
# [475]	eval-rmse:0.32858	train-rmse:0.17772
# [476]	eval-rmse:0.32858	train-rmse:0.17767
# [477]	eval-rmse:0.32856	train-rmse:0.17742
# [478]	eval-rmse:0.32855	train-rmse:0.17732
# [479]	eval-rmse:0.32855	train-rmse:0.17724
# [480]	eval-rmse:0.32855	train-rmse:0.17723
# [481]	eval-rmse:0.32854	train-rmse:0.17713
# [482]	eval-rmse:0.32854	train-rmse:0.17706
# [483]	eval-rmse:0.32853	train-rmse:0.17695
# [484]	eval-rmse:0.32852	train-rmse:0.17679
# [485]	eval-rmse:0.32852	train-rmse:0.17677
# [486]	eval-rmse:0.32852	train-rmse:0.17669
# [487]	eval-rmse:0.32851	train-rmse:0.17647
# [488]	eval-rmse:0.32851	train-rmse:0.17627
# [489]	eval-rmse:0.32851	train-rmse:0.17609
# [490]	eval-rmse:0.32849	train-rmse:0.17588
# [491]	eval-rmse:0.32848	train-rmse:0.17566
# [492]	eval-rmse:0.32847	train-rmse:0.17560
# [493]	eval-rmse:0.32847	train-rmse:0.17557
# [494]	eval-rmse:0.32847	train-rmse:0.17551
# [495]	eval-rmse:0.32847	train-rmse:0.17535
# [496]	eval-rmse:0.32847	train-rmse:0.17527
# [497]	eval-rmse:0.32843	train-rmse:0.17495
# [498]	eval-rmse:0.32841	train-rmse:0.17476
# [499]	eval-rmse:0.32841	train-rmse:0.17471
# [500]	eval-rmse:0.32841	train-rmse:0.17468
# [501]	eval-rmse:0.32841	train-rmse:0.17459
# [502]	eval-rmse:0.32841	train-rmse:0.17457
# [503]	eval-rmse:0.32839	train-rmse:0.17440
# [504]	eval-rmse:0.32838	train-rmse:0.17431
# [505]	eval-rmse:0.32838	train-rmse:0.17414
# [506]	eval-rmse:0.32838	train-rmse:0.17398
# [507]	eval-rmse:0.32837	train-rmse:0.17389
# [508]	eval-rmse:0.32837	train-rmse:0.17381
# [509]	eval-rmse:0.32838	train-rmse:0.17373
# [510]	eval-rmse:0.32837	train-rmse:0.17362
# [511]	eval-rmse:0.32837	train-rmse:0.17355
# [512]	eval-rmse:0.32837	train-rmse:0.17350
# [513]	eval-rmse:0.32837	train-rmse:0.17334
# [514]	eval-rmse:0.32835	train-rmse:0.17310
# [515]	eval-rmse:0.32830	train-rmse:0.17282
# [516]	eval-rmse:0.32829	train-rmse:0.17270
# [517]	eval-rmse:0.32829	train-rmse:0.17259
# [518]	eval-rmse:0.32829	train-rmse:0.17257
# [519]	eval-rmse:0.32828	train-rmse:0.17241
# [520]	eval-rmse:0.32826	train-rmse:0.17208
# [521]	eval-rmse:0.32825	train-rmse:0.17190
# [522]	eval-rmse:0.32825	train-rmse:0.17180
# [523]	eval-rmse:0.32824	train-rmse:0.17172
# [524]	eval-rmse:0.32823	train-rmse:0.17161
# [525]	eval-rmse:0.32823	train-rmse:0.17155
# [526]	eval-rmse:0.32823	train-rmse:0.17151
# [527]	eval-rmse:0.32822	train-rmse:0.17145
# [528]	eval-rmse:0.32822	train-rmse:0.17130
# [529]	eval-rmse:0.32822	train-rmse:0.17123
# [530]	eval-rmse:0.32822	train-rmse:0.17118
# [531]	eval-rmse:0.32822	train-rmse:0.17110
# [532]	eval-rmse:0.32822	train-rmse:0.17100
# [533]	eval-rmse:0.32821	train-rmse:0.17085
# [534]	eval-rmse:0.32821	train-rmse:0.17075
# [535]	eval-rmse:0.32821	train-rmse:0.17070
# [536]	eval-rmse:0.32821	train-rmse:0.17056
# [537]	eval-rmse:0.32821	train-rmse:0.17052
# [538]	eval-rmse:0.32820	train-rmse:0.17046
# [539]	eval-rmse:0.32820	train-rmse:0.17025
# [540]	eval-rmse:0.32820	train-rmse:0.17020
# [541]	eval-rmse:0.32820	train-rmse:0.17006
# [542]	eval-rmse:0.32819	train-rmse:0.16990
# [543]	eval-rmse:0.32819	train-rmse:0.16979
# [544]	eval-rmse:0.32817	train-rmse:0.16960
# [545]	eval-rmse:0.32816	train-rmse:0.16947
# [546]	eval-rmse:0.32815	train-rmse:0.16938
# [547]	eval-rmse:0.32816	train-rmse:0.16935
# [548]	eval-rmse:0.32815	train-rmse:0.16930
# [549]	eval-rmse:0.32815	train-rmse:0.16902
# [550]	eval-rmse:0.32813	train-rmse:0.16886
# [551]	eval-rmse:0.32813	train-rmse:0.16875
# [552]	eval-rmse:0.32813	train-rmse:0.16870
# [553]	eval-rmse:0.32813	train-rmse:0.16868
# [554]	eval-rmse:0.32813	train-rmse:0.16863
# [555]	eval-rmse:0.32813	train-rmse:0.16857
# [556]	eval-rmse:0.32813	train-rmse:0.16840
# [557]	eval-rmse:0.32812	train-rmse:0.16821
# [558]	eval-rmse:0.32812	train-rmse:0.16814
# [559]	eval-rmse:0.32812	train-rmse:0.16812
# [560]	eval-rmse:0.32812	train-rmse:0.16803
# [561]	eval-rmse:0.32812	train-rmse:0.16795
# [562]	eval-rmse:0.32812	train-rmse:0.16792
# [563]	eval-rmse:0.32812	train-rmse:0.16790
# [564]	eval-rmse:0.32811	train-rmse:0.16781
# [565]	eval-rmse:0.32811	train-rmse:0.16769
# [566]	eval-rmse:0.32811	train-rmse:0.16762
# [567]	eval-rmse:0.32811	train-rmse:0.16751
# [568]	eval-rmse:0.32811	train-rmse:0.16740
# [569]	eval-rmse:0.32810	train-rmse:0.16721
# [570]	eval-rmse:0.32810	train-rmse:0.16716
# [571]	eval-rmse:0.32810	train-rmse:0.16707
# [572]	eval-rmse:0.32810	train-rmse:0.16698
# [573]	eval-rmse:0.32809	train-rmse:0.16683
# [574]	eval-rmse:0.32809	train-rmse:0.16680
# [575]	eval-rmse:0.32809	train-rmse:0.16673
# [576]	eval-rmse:0.32808	train-rmse:0.16657
# [577]	eval-rmse:0.32808	train-rmse:0.16653
# [578]	eval-rmse:0.32808	train-rmse:0.16646
# [579]	eval-rmse:0.32808	train-rmse:0.16640
# [580]	eval-rmse:0.32808	train-rmse:0.16636
# [581]	eval-rmse:0.32808	train-rmse:0.16631
# [582]	eval-rmse:0.32808	train-rmse:0.16613
# [583]	eval-rmse:0.32808	train-rmse:0.16598
# [584]	eval-rmse:0.32808	train-rmse:0.16588
# [585]	eval-rmse:0.32807	train-rmse:0.16584
# [586]	eval-rmse:0.32807	train-rmse:0.16579
# [587]	eval-rmse:0.32807	train-rmse:0.16571
# [588]	eval-rmse:0.32807	train-rmse:0.16563
# [589]	eval-rmse:0.32807	train-rmse:0.16551
# [590]	eval-rmse:0.32806	train-rmse:0.16536
# [591]	eval-rmse:0.32806	train-rmse:0.16518
# [592]	eval-rmse:0.32805	train-rmse:0.16497
# [593]	eval-rmse:0.32805	train-rmse:0.16483
# [594]	eval-rmse:0.32805	train-rmse:0.16474
# [595]	eval-rmse:0.32805	train-rmse:0.16464
# [596]	eval-rmse:0.32803	train-rmse:0.16453
# [597]	eval-rmse:0.32803	train-rmse:0.16447
# [598]	eval-rmse:0.32803	train-rmse:0.16443
# [599]	eval-rmse:0.32804	train-rmse:0.16437
# [600]	eval-rmse:0.32803	train-rmse:0.16429
# [601]	eval-rmse:0.32802	train-rmse:0.16422
# [602]	eval-rmse:0.32802	train-rmse:0.16411
# [603]	eval-rmse:0.32801	train-rmse:0.16400
# [604]	eval-rmse:0.32801	train-rmse:0.16391
# [605]	eval-rmse:0.32801	train-rmse:0.16385
# [606]	eval-rmse:0.32801	train-rmse:0.16382
# [607]	eval-rmse:0.32800	train-rmse:0.16365
# [608]	eval-rmse:0.32800	train-rmse:0.16356
# [609]	eval-rmse:0.32800	train-rmse:0.16346
# [610]	eval-rmse:0.32800	train-rmse:0.16345
# [611]	eval-rmse:0.32800	train-rmse:0.16333
# [612]	eval-rmse:0.32800	train-rmse:0.16326
# [613]	eval-rmse:0.32799	train-rmse:0.16312
# [614]	eval-rmse:0.32798	train-rmse:0.16299
# [615]	eval-rmse:0.32798	train-rmse:0.16294
# [616]	eval-rmse:0.32798	train-rmse:0.16289
# [617]	eval-rmse:0.32797	train-rmse:0.16275
# [618]	eval-rmse:0.32797	train-rmse:0.16265
# [619]	eval-rmse:0.32797	train-rmse:0.16262
# [620]	eval-rmse:0.32797	train-rmse:0.16259
# [621]	eval-rmse:0.32797	train-rmse:0.16251
# [622]	eval-rmse:0.32796	train-rmse:0.16240
# [623]	eval-rmse:0.32797	train-rmse:0.16232
# [624]	eval-rmse:0.32796	train-rmse:0.16217
# [625]	eval-rmse:0.32795	train-rmse:0.16201
# [626]	eval-rmse:0.32794	train-rmse:0.16194
# [627]	eval-rmse:0.32794	train-rmse:0.16191
# [628]	eval-rmse:0.32794	train-rmse:0.16187
# [629]	eval-rmse:0.32794	train-rmse:0.16180
# [630]	eval-rmse:0.32794	train-rmse:0.16170
# [631]	eval-rmse:0.32793	train-rmse:0.16164
# [632]	eval-rmse:0.32793	train-rmse:0.16153
# [633]	eval-rmse:0.32793	train-rmse:0.16149
# [634]	eval-rmse:0.32793	train-rmse:0.16140
# [635]	eval-rmse:0.32793	train-rmse:0.16137
# [636]	eval-rmse:0.32793	train-rmse:0.16128
# [637]	eval-rmse:0.32793	train-rmse:0.16120
# [638]	eval-rmse:0.32793	train-rmse:0.16114
# [639]	eval-rmse:0.32794	train-rmse:0.16111
# [640]	eval-rmse:0.32793	train-rmse:0.16104
# [641]	eval-rmse:0.32793	train-rmse:0.16096
# [642]	eval-rmse:0.32792	train-rmse:0.16087
# [643]	eval-rmse:0.32792	train-rmse:0.16082
# [644]	eval-rmse:0.32793	train-rmse:0.16080
# [645]	eval-rmse:0.32793	train-rmse:0.16076
# [646]	eval-rmse:0.32793	train-rmse:0.16070
# [647]	eval-rmse:0.32793	train-rmse:0.16063
# [648]	eval-rmse:0.32793	train-rmse:0.16057
# [649]	eval-rmse:0.32793	train-rmse:0.16054
# [650]	eval-rmse:0.32793	train-rmse:0.16045
# [651]	eval-rmse:0.32793	train-rmse:0.16038
# [652]	eval-rmse:0.32793	train-rmse:0.16033
# [653]	eval-rmse:0.32793	train-rmse:0.16030
# [654]	eval-rmse:0.32791	train-rmse:0.16016
# [655]	eval-rmse:0.32791	train-rmse:0.16009
# [656]	eval-rmse:0.32791	train-rmse:0.16005
# [657]	eval-rmse:0.32791	train-rmse:0.15994
# [658]	eval-rmse:0.32791	train-rmse:0.15987
# [659]	eval-rmse:0.32789	train-rmse:0.15976
# [660]	eval-rmse:0.32789	train-rmse:0.15971
# [661]	eval-rmse:0.32789	train-rmse:0.15962
# [662]	eval-rmse:0.32789	train-rmse:0.15960
# [663]	eval-rmse:0.32788	train-rmse:0.15952
# [664]	eval-rmse:0.32789	train-rmse:0.15937
# [665]	eval-rmse:0.32789	train-rmse:0.15932
# [666]	eval-rmse:0.32787	train-rmse:0.15914
# [667]	eval-rmse:0.32787	train-rmse:0.15899
# [668]	eval-rmse:0.32787	train-rmse:0.15890
# [669]	eval-rmse:0.32787	train-rmse:0.15877
# [670]	eval-rmse:0.32786	train-rmse:0.15854
# [671]	eval-rmse:0.32785	train-rmse:0.15840
# [672]	eval-rmse:0.32786	train-rmse:0.15832
# [673]	eval-rmse:0.32786	train-rmse:0.15826
# [674]	eval-rmse:0.32786	train-rmse:0.15819
# [675]	eval-rmse:0.32786	train-rmse:0.15809
# [676]	eval-rmse:0.32786	train-rmse:0.15793
# [677]	eval-rmse:0.32785	train-rmse:0.15785
# [678]	eval-rmse:0.32785	train-rmse:0.15776
# [679]	eval-rmse:0.32785	train-rmse:0.15771
# [680]	eval-rmse:0.32785	train-rmse:0.15764
# [681]	eval-rmse:0.32785	train-rmse:0.15760
# [682]	eval-rmse:0.32785	train-rmse:0.15756
# [683]	eval-rmse:0.32784	train-rmse:0.15736
# [684]	eval-rmse:0.32784	train-rmse:0.15730
# [685]	eval-rmse:0.32784	train-rmse:0.15724
# [686]	eval-rmse:0.32784	train-rmse:0.15719
# [687]	eval-rmse:0.32784	train-rmse:0.15710
# [688]	eval-rmse:0.32784	train-rmse:0.15702
# [689]	eval-rmse:0.32784	train-rmse:0.15696
# [690]	eval-rmse:0.32784	train-rmse:0.15689
# [691]	eval-rmse:0.32784	train-rmse:0.15685
# [692]	eval-rmse:0.32784	train-rmse:0.15680
# [693]	eval-rmse:0.32784	train-rmse:0.15668
# [694]	eval-rmse:0.32783	train-rmse:0.15661
# [695]	eval-rmse:0.32784	train-rmse:0.15654
# [696]	eval-rmse:0.32784	train-rmse:0.15651
# [697]	eval-rmse:0.32783	train-rmse:0.15639
# [698]	eval-rmse:0.32783	train-rmse:0.15633
# [699]	eval-rmse:0.32783	train-rmse:0.15622
# [700]	eval-rmse:0.32782	train-rmse:0.15615
# [701]	eval-rmse:0.32782	train-rmse:0.15610
# [702]	eval-rmse:0.32782	train-rmse:0.15604
# [703]	eval-rmse:0.32782	train-rmse:0.15600
# [704]	eval-rmse:0.32782	train-rmse:0.15596
# [705]	eval-rmse:0.32782	train-rmse:0.15592
# [706]	eval-rmse:0.32782	train-rmse:0.15588
# [707]	eval-rmse:0.32781	train-rmse:0.15578
# [708]	eval-rmse:0.32781	train-rmse:0.15574
# [709]	eval-rmse:0.32781	train-rmse:0.15561
# [710]	eval-rmse:0.32781	train-rmse:0.15557
# [711]	eval-rmse:0.32779	train-rmse:0.15546
# [712]	eval-rmse:0.32779	train-rmse:0.15541
# [713]	eval-rmse:0.32778	train-rmse:0.15533
# [714]	eval-rmse:0.32777	train-rmse:0.15520
# [715]	eval-rmse:0.32776	train-rmse:0.15509
# [716]	eval-rmse:0.32777	train-rmse:0.15503
# [717]	eval-rmse:0.32777	train-rmse:0.15499
# [718]	eval-rmse:0.32776	train-rmse:0.15486
# [719]	eval-rmse:0.32775	train-rmse:0.15472
# [720]	eval-rmse:0.32776	train-rmse:0.15469
# [721]	eval-rmse:0.32776	train-rmse:0.15463
# [722]	eval-rmse:0.32776	train-rmse:0.15458
# [723]	eval-rmse:0.32775	train-rmse:0.15449
# [724]	eval-rmse:0.32775	train-rmse:0.15437
# [725]	eval-rmse:0.32775	train-rmse:0.15427
# [726]	eval-rmse:0.32775	train-rmse:0.15413
# [727]	eval-rmse:0.32775	train-rmse:0.15404
# [728]	eval-rmse:0.32775	train-rmse:0.15394
# [729]	eval-rmse:0.32775	train-rmse:0.15384
# [730]	eval-rmse:0.32774	train-rmse:0.15378
# [731]	eval-rmse:0.32774	train-rmse:0.15370
# [732]	eval-rmse:0.32775	train-rmse:0.15361
# [733]	eval-rmse:0.32774	train-rmse:0.15358
# [734]	eval-rmse:0.32774	train-rmse:0.15351
# [735]	eval-rmse:0.32773	train-rmse:0.15337
# [736]	eval-rmse:0.32773	train-rmse:0.15329
# [737]	eval-rmse:0.32773	train-rmse:0.15321
# [738]	eval-rmse:0.32773	train-rmse:0.15312
# [739]	eval-rmse:0.32772	train-rmse:0.15299
# [740]	eval-rmse:0.32772	train-rmse:0.15294
# [741]	eval-rmse:0.32772	train-rmse:0.15283
# [742]	eval-rmse:0.32772	train-rmse:0.15278
# [743]	eval-rmse:0.32772	train-rmse:0.15272
# [744]	eval-rmse:0.32771	train-rmse:0.15255
# [745]	eval-rmse:0.32770	train-rmse:0.15237
# [746]	eval-rmse:0.32770	train-rmse:0.15227
# [747]	eval-rmse:0.32770	train-rmse:0.15217
# [748]	eval-rmse:0.32770	train-rmse:0.15211
# [749]	eval-rmse:0.32770	train-rmse:0.15204
# [750]	eval-rmse:0.32770	train-rmse:0.15195
# [751]	eval-rmse:0.32770	train-rmse:0.15180
# [752]	eval-rmse:0.32770	train-rmse:0.15173
# [753]	eval-rmse:0.32770	train-rmse:0.15172
# [754]	eval-rmse:0.32770	train-rmse:0.15163
# [755]	eval-rmse:0.32770	train-rmse:0.15152
# [756]	eval-rmse:0.32770	train-rmse:0.15146
# [757]	eval-rmse:0.32770	train-rmse:0.15141
# [758]	eval-rmse:0.32770	train-rmse:0.15136
# [759]	eval-rmse:0.32770	train-rmse:0.15132
# [760]	eval-rmse:0.32769	train-rmse:0.15124
# [761]	eval-rmse:0.32769	train-rmse:0.15119
# [762]	eval-rmse:0.32769	train-rmse:0.15114
# [763]	eval-rmse:0.32768	train-rmse:0.15107
# [764]	eval-rmse:0.32768	train-rmse:0.15102
# [765]	eval-rmse:0.32768	train-rmse:0.15094
# [821]	eval-rmse:0.32761	train-rmse:0.14706
# [822]	eval-rmse:0.32761	train-rmse:0.14705
# [823]	eval-rmse:0.32761	train-rmse:0.14699
# [824]	eval-rmse:0.32761	train-rmse:0.14696
# [825]	eval-rmse:0.32761	train-rmse:0.14694
# [826]	eval-rmse:0.32761	train-rmse:0.14684
# [827]	eval-rmse:0.32761	train-rmse:0.14681
# [828]	eval-rmse:0.32761	train-rmse:0.14668
# [829]	eval-rmse:0.32760	train-rmse:0.14660
# [830]	eval-rmse:0.32760	train-rmse:0.14653
# [831]	eval-rmse:0.32761	train-rmse:0.14650
# [832]	eval-rmse:0.32760	train-rmse:0.14645
# [833]	eval-rmse:0.32760	train-rmse:0.14636
# [834]	eval-rmse:0.32760	train-rmse:0.14625
# [835]	eval-rmse:0.32760	train-rmse:0.14621
# [836]	eval-rmse:0.32759	train-rmse:0.14607
# [837]	eval-rmse:0.32759	train-rmse:0.14604
# [838]	eval-rmse:0.32759	train-rmse:0.14597
# [839]	eval-rmse:0.32759	train-rmse:0.14590
# [840]	eval-rmse:0.32759	train-rmse:0.14585
# [841]	eval-rmse:0.32759	train-rmse:0.14580
# [842]	eval-rmse:0.32758	train-rmse:0.14567
# [843]	eval-rmse:0.32758	train-rmse:0.14561
# [844]	eval-rmse:0.32757	train-rmse:0.14555
# [845]	eval-rmse:0.32757	train-rmse:0.14543
# [846]	eval-rmse:0.32757	train-rmse:0.14538
# [847]	eval-rmse:0.32757	train-rmse:0.14530
# [848]	eval-rmse:0.32757	train-rmse:0.14513
# [849]	eval-rmse:0.32758	train-rmse:0.14507
# [850]	eval-rmse:0.32758	train-rmse:0.14502
# [851]	eval-rmse:0.32758	train-rmse:0.14496
# [852]	eval-rmse:0.32758	train-rmse:0.14491
# [853]	eval-rmse:0.32758	train-rmse:0.14486
# [854]	eval-rmse:0.32758	train-rmse:0.14480
# [855]	eval-rmse:0.32758	train-rmse:0.14478
# [856]	eval-rmse:0.32758	train-rmse:0.14475
# [857]	eval-rmse:0.32758	train-rmse:0.14465
# [858]	eval-rmse:0.32757	train-rmse:0.14459
# [859]	eval-rmse:0.32757	train-rmse:0.14450
# [860]	eval-rmse:0.32758	train-rmse:0.14444
# [861]	eval-rmse:0.32758	train-rmse:0.14439
# [862]	eval-rmse:0.32758	train-rmse:0.14433
# [863]	eval-rmse:0.32758	train-rmse:0.14431
# [864]	eval-rmse:0.32758	train-rmse:0.14424
# [865]	eval-rmse:0.32758	train-rmse:0.14418
# [866]	eval-rmse:0.32757	train-rmse:0.14402
# [867]	eval-rmse:0.32757	train-rmse:0.14392
# [868]	eval-rmse:0.32757	train-rmse:0.14381
# [869]	eval-rmse:0.32757	train-rmse:0.14377
# [870]	eval-rmse:0.32756	train-rmse:0.14368
# [871]	eval-rmse:0.32756	train-rmse:0.14358
# [872]	eval-rmse:0.32755	train-rmse:0.14351
# [873]	eval-rmse:0.32755	train-rmse:0.14340
# [874]	eval-rmse:0.32755	train-rmse:0.14336
# [875]	eval-rmse:0.32755	train-rmse:0.14331
# [876]	eval-rmse:0.32755	train-rmse:0.14322
# [877]	eval-rmse:0.32755	train-rmse:0.14317
# [878]	eval-rmse:0.32755	train-rmse:0.14311
# [879]	eval-rmse:0.32755	train-rmse:0.14306
# [880]	eval-rmse:0.32755	train-rmse:0.14298
# [881]	eval-rmse:0.32755	train-rmse:0.14295
# [882]	eval-rmse:0.32755	train-rmse:0.14285
# [883]	eval-rmse:0.32755	train-rmse:0.14280
# [884]	eval-rmse:0.32755	train-rmse:0.14266
# [885]	eval-rmse:0.32755	train-rmse:0.14260
# [886]	eval-rmse:0.32755	train-rmse:0.14256
# [887]	eval-rmse:0.32755	train-rmse:0.14253
# [888]	eval-rmse:0.32753	train-rmse:0.14235
# [889]	eval-rmse:0.32753	train-rmse:0.14230
# [890]	eval-rmse:0.32753	train-rmse:0.14219
# [891]	eval-rmse:0.32752	train-rmse:0.14206
# [892]	eval-rmse:0.32752	train-rmse:0.14202
# [893]	eval-rmse:0.32751	train-rmse:0.14190
# [894]	eval-rmse:0.32750	train-rmse:0.14183
# [895]	eval-rmse:0.32750	train-rmse:0.14176
# [896]	eval-rmse:0.32750	train-rmse:0.14164
# [897]	eval-rmse:0.32750	train-rmse:0.14156
# [898]	eval-rmse:0.32750	train-rmse:0.14152
# [899]	eval-rmse:0.32750	train-rmse:0.14150
# [900]	eval-rmse:0.32750	train-rmse:0.14142
# [901]	eval-rmse:0.32749	train-rmse:0.14136
# [902]	eval-rmse:0.32749	train-rmse:0.14130
# [903]	eval-rmse:0.32749	train-rmse:0.14125
# [904]	eval-rmse:0.32749	train-rmse:0.14123
# [905]	eval-rmse:0.32749	train-rmse:0.14116
# [906]	eval-rmse:0.32749	train-rmse:0.14108
# [907]	eval-rmse:0.32748	train-rmse:0.14100
# [908]	eval-rmse:0.32748	train-rmse:0.14095
# [909]	eval-rmse:0.32748	train-rmse:0.14088
# [910]	eval-rmse:0.32748	train-rmse:0.14082
# [911]	eval-rmse:0.32747	train-rmse:0.14067
# [912]	eval-rmse:0.32747	train-rmse:0.14063
# [913]	eval-rmse:0.32747	train-rmse:0.14051
# [914]	eval-rmse:0.32747	train-rmse:0.14043
# [915]	eval-rmse:0.32747	train-rmse:0.14039
# [916]	eval-rmse:0.32747	train-rmse:0.14031
# [917]	eval-rmse:0.32747	train-rmse:0.14022
# [918]	eval-rmse:0.32747	train-rmse:0.14016
# [919]	eval-rmse:0.32747	train-rmse:0.14015
# [920]	eval-rmse:0.32747	train-rmse:0.14008
# [921]	eval-rmse:0.32746	train-rmse:0.14003
# [922]	eval-rmse:0.32746	train-rmse:0.13994
# [923]	eval-rmse:0.32745	train-rmse:0.13982
# [924]	eval-rmse:0.32745	train-rmse:0.13975
# [925]	eval-rmse:0.32745	train-rmse:0.13969
# [926]	eval-rmse:0.32745	train-rmse:0.13966
# [927]	eval-rmse:0.32745	train-rmse:0.13955
# [928]	eval-rmse:0.32745	train-rmse:0.13951
# [929]	eval-rmse:0.32745	train-rmse:0.13942
# [930]	eval-rmse:0.32745	train-rmse:0.13940
# [931]	eval-rmse:0.32745	train-rmse:0.13934
# [1096]	eval-rmse:0.32733	train-rmse:0.12903
# [1097]	eval-rmse:0.32733	train-rmse:0.12898
# [1098]	eval-rmse:0.32733	train-rmse:0.12892
# [1099]	eval-rmse:0.32733	train-rmse:0.12886
# [1100]	eval-rmse:0.32733	train-rmse:0.12881
# [1101]	eval-rmse:0.32733	train-rmse:0.12876
# [1102]	eval-rmse:0.32733	train-rmse:0.12870
# ...
# [1641]	eval-rmse:0.32716	train-rmse:0.10317
# [1642]	eval-rmse:0.32716	train-rmse:0.10311
# [1643]	eval-rmse:0.32716	train-rmse:0.10308
# [1644]	eval-rmse:0.32716	train-rmse:0.10304
# [1645]	eval-rmse:0.32716	train-rmse:0.10302
# [1646]	eval-rmse:0.32716	train-rmse:0.10298
# [1647]	eval-rmse:0.32716	train-rmse:0.10295
# [1648]	eval-rmse:0.32716	train-rmse:0.10292
# [1649]	eval-rmse:0.32716	train-rmse:0.10289
# [1650]	eval-rmse:0.32716	train-rmse:0.10286
# [1651]	eval-rmse:0.32716	train-rmse:0.10283
# [1652]	eval-rmse:0.32716	train-rmse:0.10279
# [1653]	eval-rmse:0.32716	train-rmse:0.10276
# [1654]	eval-rmse:0.32716	train-rmse:0.10272
# [1655]	eval-rmse:0.32716	train-rmse:0.10268
# [1656]	eval-rmse:0.32716	train-rmse:0.10266
# [1657]	eval-rmse:0.32716	train-rmse:0.10260
# [1658]	eval-rmse:0.32716	train-rmse:0.10258
# [1659]	eval-rmse:0.32716	train-rmse:0.10254
# [1660]	eval-rmse:0.32716	train-rmse:0.10251
# [1661]	eval-rmse:0.32716	train-rmse:0.10246
# [1662]	eval-rmse:0.32716	train-rmse:0.10241
# [1663]	eval-rmse:0.32716	train-rmse:0.10236
# [1664]	eval-rmse:0.32716	train-rmse:0.10232
# [1665]	eval-rmse:0.32716	train-rmse:0.10230
# [1666]	eval-rmse:0.32716	train-rmse:0.10229
# [1667]	eval-rmse:0.32716	train-rmse:0.10225
# [1668]	eval-rmse:0.32716	train-rmse:0.10222
# [1669]	eval-rmse:0.32716	train-rmse:0.10217
# [1670]	eval-rmse:0.32716	train-rmse:0.10216
# [1671]	eval-rmse:0.32716	train-rmse:0.10211
# [1672]	eval-rmse:0.32716	train-rmse:0.10207
# [1673]	eval-rmse:0.32716	train-rmse:0.10202
# [1674]	eval-rmse:0.32716	train-rmse:0.10201
# [1675]	eval-rmse:0.32716	train-rmse:0.10198
# [1676]	eval-rmse:0.32716	train-rmse:0.10192
# [1677]	eval-rmse:0.32716	train-rmse:0.10189
# [1678]	eval-rmse:0.32716	train-rmse:0.10183
# [1679]	eval-rmse:0.32716	train-rmse:0.10179
# [1680]	eval-rmse:0.32716	train-rmse:0.10173
# [1681]	eval-rmse:0.32716	train-rmse:0.10171
# [1682]	eval-rmse:0.32716	train-rmse:0.10165
# [1683]	eval-rmse:0.32716	train-rmse:0.10164
# [1684]	eval-rmse:0.32716	train-rmse:0.10159
# [1685]	eval-rmse:0.32716	train-rmse:0.10155
# [1686]	eval-rmse:0.32716	train-rmse:0.10151
# [1687]	eval-rmse:0.32716	train-rmse:0.10149
# [1688]	eval-rmse:0.32716	train-rmse:0.10147
# [1689]	eval-rmse:0.32716	train-rmse:0.10146
# [1690]	eval-rmse:0.32716	train-rmse:0.10143
# [1691]	eval-rmse:0.32716	train-rmse:0.10135
# [1692]	eval-rmse:0.32716	train-rmse:0.10126
# [1693]	eval-rmse:0.32716	train-rmse:0.10124
# [1694]	eval-rmse:0.32716	train-rmse:0.10121
# [1695]	eval-rmse:0.32716	train-rmse:0.10115
# [1696]	eval-rmse:0.32716	train-rmse:0.10110
# [1697]	eval-rmse:0.32716	train-rmse:0.10105
# [1698]	eval-rmse:0.32716	train-rmse:0.10102
# [1699]	eval-rmse:0.32716	train-rmse:0.10098
# [1700]	eval-rmse:0.32716	train-rmse:0.10095
# [1701]	eval-rmse:0.32716	train-rmse:0.10093
# [1702]	eval-rmse:0.32716	train-rmse:0.10088
# [1703]	eval-rmse:0.32716	train-rmse:0.10085
# [1704]	eval-rmse:0.32716	train-rmse:0.10081
# [1705]	eval-rmse:0.32716	train-rmse:0.10077
# [1706]	eval-rmse:0.32716	train-rmse:0.10070
# [1707]	eval-rmse:0.32716	train-rmse:0.10066
# [1708]	eval-rmse:0.32716	train-rmse:0.10063
# [1709]	eval-rmse:0.32716	train-rmse:0.10061
# [1710]	eval-rmse:0.32716	train-rmse:0.10057
# [1711]	eval-rmse:0.32716	train-rmse:0.10054
# [1712]	eval-rmse:0.32716	train-rmse:0.10051
# [1713]	eval-rmse:0.32716	train-rmse:0.10043
# [1714]	eval-rmse:0.32716	train-rmse:0.10036
# [1715]	eval-rmse:0.32716	train-rmse:0.10033
# [1716]	eval-rmse:0.32716	train-rmse:0.10029
# [1717]	eval-rmse:0.32716	train-rmse:0.10024
# [1718]	eval-rmse:0.32716	train-rmse:0.10019
# [1719]	eval-rmse:0.32716	train-rmse:0.10014
# [1720]	eval-rmse:0.32716	train-rmse:0.10001
# [1721]	eval-rmse:0.32716	train-rmse:0.09997
# [1722]	eval-rmse:0.32716	train-rmse:0.09992
# [1723]	eval-rmse:0.32716	train-rmse:0.09989
# [1724]	eval-rmse:0.32716	train-rmse:0.09985
# [1725]	eval-rmse:0.32716	train-rmse:0.09982
# [1726]	eval-rmse:0.32716	train-rmse:0.09980
# [1727]	eval-rmse:0.32716	train-rmse:0.09975
# [1728]	eval-rmse:0.32715	train-rmse:0.09970
# [1729]	eval-rmse:0.32715	train-rmse:0.09965
# [1730]	eval-rmse:0.32715	train-rmse:0.09964
# [1731]	eval-rmse:0.32715	train-rmse:0.09959
# [1732]	eval-rmse:0.32715	train-rmse:0.09954
# [1733]	eval-rmse:0.32715	train-rmse:0.09948
# [1734]	eval-rmse:0.32715	train-rmse:0.09943
# [1735]	eval-rmse:0.32715	train-rmse:0.09940
# [1736]	eval-rmse:0.32715	train-rmse:0.09937
# [1737]	eval-rmse:0.32714	train-rmse:0.09925
# [1738]	eval-rmse:0.32714	train-rmse:0.09923
# [1739]	eval-rmse:0.32714	train-rmse:0.09919
# [1740]	eval-rmse:0.32714	train-rmse:0.09916
# [1956]	eval-rmse:0.32714	train-rmse:0.09188
# [1957]	eval-rmse:0.32714	train-rmse:0.09186
# [1958]	eval-rmse:0.32714	train-rmse:0.09182
# [1959]	eval-rmse:0.32714	train-rmse:0.09181
# [1960]	eval-rmse:0.32714	train-rmse:0.09176
# [1961]	eval-rmse:0.32714	train-rmse:0.09171
# [1962]	eval-rmse:0.32714	train-rmse:0.09169
# [1963]	eval-rmse:0.32714	train-rmse:0.09167
# [1964]	eval-rmse:0.32714	train-rmse:0.09166
# [1965]	eval-rmse:0.32714	train-rmse:0.09163
# [1966]	eval-rmse:0.32714	train-rmse:0.09160
# [1967]	eval-rmse:0.32714	train-rmse:0.09158
# [1968]	eval-rmse:0.32714	train-rmse:0.09155
# [1969]	eval-rmse:0.32714	train-rmse:0.09152
# [1970]	eval-rmse:0.32714	train-rmse:0.09150
# [1971]	eval-rmse:0.32714	train-rmse:0.09146
# [1972]	eval-rmse:0.32714	train-rmse:0.09144
# [1973]	eval-rmse:0.32714	train-rmse:0.09142
# [1974]	eval-rmse:0.32714	train-rmse:0.09138
# [1975]	eval-rmse:0.32714	train-rmse:0.09136
# [1976]	eval-rmse:0.32714	train-rmse:0.09132
# [1977]	eval-rmse:0.32714	train-rmse:0.09129
# [1978]	eval-rmse:0.32714	train-rmse:0.09126
# [1979]	eval-rmse:0.32714	train-rmse:0.09121
# [1980]	eval-rmse:0.32714	train-rmse:0.09119
# [1981]	eval-rmse:0.32714	train-rmse:0.09116
# [1982]	eval-rmse:0.32714	train-rmse:0.09114
# [1983]	eval-rmse:0.32714	train-rmse:0.09111
# [1984]	eval-rmse:0.32714	train-rmse:0.09107
# [1985]	eval-rmse:0.32714	train-rmse:0.09105
# [1986]	eval-rmse:0.32714	train-rmse:0.09102
# [1987]	eval-rmse:0.32714	train-rmse:0.09099
# [1988]	eval-rmse:0.32714	train-rmse:0.09096
# [1989]	eval-rmse:0.32714	train-rmse:0.09093
# [1990]	eval-rmse:0.32714	train-rmse:0.09090
# [1991]	eval-rmse:0.32714	train-rmse:0.09087
# [1992]	eval-rmse:0.32714	train-rmse:0.09082
# [1993]	eval-rmse:0.32713	train-rmse:0.09078
# [1994]	eval-rmse:0.32713	train-rmse:0.09070
# [1995]	eval-rmse:0.32714	train-rmse:0.09067
# [1996]	eval-rmse:0.32714	train-rmse:0.09064
# [1997]	eval-rmse:0.32713	train-rmse:0.09063
# [1998]	eval-rmse:0.32714	train-rmse:0.09059
# [1999]	eval-rmse:0.32714	train-rmse:0.09057
# [02:26:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.

# %%
#Test predictions
pred = np.exp(gbm.predict(xgb.DMatrix(X_test))) - 1

# %%
#Use mean absolute error to get a basic estimate of the error
mae = (abs(pred - y_test)).mean()
mae
# Out:
# 4.8215870279440365

# %%
#Take a look at feature importance
feature_scores = gbm.get_fscore()
feature_scores
# Out:
# {'latitude_difference': 503200,
#  'trip_distance': 454740,
#  'pickup_latitude': 755256,
#  'pickup_weekday': 217697,
#  'dropoff_longitude': 674020,
#  'pickup_month': 241243,
#  'passenger_count': 245093,
#  'pickup_minute': 414737,
#  'store_and_fwd_flag': 5590,
#  'longitude_difference': 450291,
#  'pickup_hour': 350519,
#  'pickup_longitude': 827080,
#  'pickup_day': 394199,
#  'dropoff_latitude': 631465}

# %%
#This is not very telling, so let's scale the features
summ = 0
for key in feature_scores:
    summ = summ + feature_scores[key]

for key in feature_scores:
    feature_scores[key] = feature_scores[key] / summ

feature_scores
# Out:
# {'latitude_difference': 0.08162033890607336,
#  'trip_distance': 0.0737600018166689,
#  'pickup_latitude': 0.12250447273617912,
#  'pickup_weekday': 0.03531101533949811,
#  'dropoff_longitude': 0.10932778384235206,
#  'pickup_month': 0.03913023731859669,
#  'passenger_count': 0.03975471725657042,
#  'pickup_minute': 0.0672714119572499,
#  'store_and_fwd_flag': 0.0009067124294216018,
#  'longitude_difference': 0.07303836253250134,
#  'pickup_hour': 0.05685508659184802,
#  'pickup_longitude': 0.134154510934887,
#  'pickup_day': 0.06394009534267728,
#  'dropoff_latitude': 0.10242525299547617}

# %%
filename = "xgb_model.sav"
pickle.dump(gbm, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
# Out:
# [03:01:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model

# %% [markdown]
# # Genetic Algorithm

# %%
#Sample date
import datetime
date_list = [4, 6, 2016] #April 6, 2016

year = int(date_list[2])
month = int(date_list[1])
day = int(date_list[0])

my_date = datetime.date(year, month, day)

# %%
#Sample test locations

test_locations = {'L1': (40.819688, -73.915091),
                  'L2': (40.815421, -73.941761),
                  'L3': (40.764198, -73.910785),
                  'L4': (40.768790, -73.953285),
                  'L5': (40.734851, -73.952950),
                  'L6': (40.743613, -73.977998),
                  'L7': (40.745313, -73.993793),
                  'L8': (40.662713, -73.946101),
                  'L9': (40.703761, -73.886496),
                  'L10': (40.713620, -73.943076),
                  'L11': (40.725212, -73.809179)
             }

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="test/2")
addresses = []

for key in test_locations:
    location = geolocator.reverse(test_locations[key])
    addresses.append(location.address)

# %%
addresses
# Out:
# ['424, East 155th Street, The Bronx, Bronx County, New York, 10455, United States of America',
#  '137, West 136th Street, Harlem, Manhattan Community Board 10, Manhattan, New York County, New York, 10030, United States of America',
#  '43-11, 28th Avenue, Queens, Queens County, New York, 11103, United States of America',
#  '435, East 74th Street, Upper East Side, Manhattan Community Board 8, Manhattan, New York County, New York, 10021, United States of America',
#  '211, Freeman Street, Brooklyn, Kings County, New York, 11222, United States of America',
#  '232, East 32nd Street, Manhattan Community Board 6, Manhattan, New York County, New York, 10016, United States of America',
#  '159, West 25th Street, Flatiron District, Manhattan Community Board 5, Manhattan, New York County, New York, 10001, United States of America',
#  '458, Lefferts Avenue, Crown Heights, Brooklyn, Kings County, New York, 11225, United States of America',
#  '70-38, 67th Place, Queens, Queens County, New York, 11385, United States of America',
#  '194, Devoe Street, Williamsburg, Brooklyn, Kings County, New York, 11211, United States of America',
#  '158-46, 76th Avenue, Queens, Queens County, New York, 11366, United States of America']

# %%
test_addresses = {'L1': '424 East 155th Street NY',
                  'L2': '137 West 136th Street NY',
                  'L3': '43-11 28th Avenue NY',
                  'L4': '435 East 74th Street NY',
                  'L5': '211 Freeman Street NY',
                  'L6': '232 East 32nd Street NY',
                  'L7': '159 West 25th Street NY',
                  'L8': '486 Brooklyn Avenue NY',
                  'L9': '70-38 67th Place NY',
                  'L10': '194 Devoe Street NY',
                  'L11': '158-46 76th Avenue NY'
             }

# %%
def create_guess(points):
    """
    Creates a possible path between all points, returning to the original.
    Input: List of point IDs
    """
    guess = points
    np.random.shuffle(guess)
    guess.append(guess[0])
    return list(guess)

create_guess(list(test_locations.keys()))
# Out:
# ['L11', 'L10', 'L5', 'L3', 'L1', 'L9', 'L6', 'L4', 'L7', 'L2', 'L8', 'L11']

# %%
def create_generation(points, population=100):
    """
    Makes a list of guessed point orders given a list of point IDs.
    Input:
    points: list of point ids
    population: how many guesses to make
    """
    generation = [create_guess(points) for _ in range(population)]
    return generation

test_generation = create_generation(list(test_locations.keys()), population=10)
print(test_generation)
# Out:
# [['L9', 'L5', 'L3', 'L11', 'L6', 'L2', 'L8', 'L7', 'L4', 'L10', 'L1', 'L9'], ['L2', 'L5', 'L7', 'L4', 'L3', 'L9', 'L6', 'L1', 'L8', 'L10', 'L9', 'L11', 'L2'], ['L6', 'L9', 'L2', 'L7', 'L2', 'L5', 'L4', 'L9', 'L1', 'L8', 'L3', 'L11', 'L10', 'L6'], ['L1', 'L6', 'L8', 'L6', 'L9', 'L5', 'L9', 'L10', 'L11', 'L7', 'L4', 'L2', 'L2', 'L3', 'L1'], ['L1', 'L9', 'L2', 'L9', 'L1', 'L5', 'L3', 'L6', 'L6', 'L2', 'L10', 'L8', 'L4', 'L11', 'L7', 'L1'], ['L2', 'L10', 'L1', 'L7', 'L4', 'L6', 'L5', 'L11', 'L6', 'L9', 'L2', 'L1', 'L3', 'L1', 'L8', 'L9', 'L2'], ['L2', 'L2', 'L4', 'L5', 'L8', 'L6', 'L10', 'L11', 'L1', 'L7', 'L6', 'L1', 'L9', 'L3', 'L9', 'L1', 'L2', 'L2'], ['L4', 'L9', 'L2', 'L1', 'L2', 'L2', 'L1', 'L5', 'L2', 'L10', 'L11', 'L6', 'L3', 'L8', 'L6', 'L1', 'L7', 'L9', 'L4'], ['L2', 'L2', 'L9', 'L6', 'L4', 'L6', 'L8', 'L1', 'L10', 'L9', 'L7', 'L2', 'L3', 'L5', 'L4', 'L11', 'L2', 'L1', 'L1', 'L2'], ['L1', 'L10', 'L2', 'L3', 'L9', 'L4', 'L5', 'L2', 'L1', 'L1', 'L6', 'L6', 'L4', 'L7', 'L8', 'L11', 'L2', 'L2', 'L2', 'L9', 'L1']]

# %%
def travel_time_between_points(point1_id, point2_id, hour, date, passenger_count = 1, 
                               store_and_fwd_flag = 0, pickup_minute = 0):
    """
    Given two points, this calculates travel between them based on a XGBoost predictive model
    """
    
    model_data = {'passenger_count': passenger_count,
                  'pickup_longitude' : point1_id[1],
                  'pickup_latitude' : point1_id[0],
                  'dropoff_longitude' : point2_id[1],
                  'dropoff_latitude' : point2_id[0],
                  'store_and_fwd_flag' : store_and_fwd_flag,
                  'pickup_month' : my_date.month,
                  'pickup_day' : my_date.day,
                  'pickup_weekday' : my_date.weekday(),
                  'pickup_hour': hour,
                  'pickup_minute' : pickup_minute,
                  'latitude_difference' : point2_id[0] - point1_id[0],
                  'longitude_difference' : point2_id[1] - point1_id[1],
                  'trip_distance' : 0.621371 * 6371 * (abs(2 * np.arctan2(np.sqrt(np.square(np.sin((abs(point2_id[0] - point1_id[0]) * np.pi / 180) / 2))), 
                                  np.sqrt(1-(np.square(np.sin((abs(point2_id[0] - point1_id[0]) * np.pi / 180) / 2)))))) + \
                                     abs(2 * np.arctan2(np.sqrt(np.square(np.sin((abs(point2_id[1] - point1_id[1]) * np.pi / 180) / 2))), 
                                  np.sqrt(1-(np.square(np.sin((abs(point2_id[1] - point1_id[1]) * np.pi / 180) / 2)))))))
                 }

    df = pd.DataFrame([model_data], columns=model_data.keys())
    
    pred = np.exp(loaded_model.predict(xgb.DMatrix(df))) - 1
    
    return pred[0]

# %%
coordinates = test_locations

# %%
def fitness_score(guess):
    """
    Loops through the points in the guesses order and calculates
    how much distance the path would take to complete a loop.
    Lower is better.
    """
    score = 0
    for ix, point_id in enumerate(guess[:-1]):
        score += travel_time_between_points(coordinates[point_id], coordinates[guess[ix+1]], 11, my_date)
    return score

def check_fitness(guesses):
    """
    Goes through every guess and calculates the fitness score. 
    Returns a list of tuples: (guess, fitness_score)
    """
    fitness_indicator = []
    for guess in guesses:
        fitness_indicator.append((guess, fitness_score(guess)))
    return fitness_indicator

print(check_fitness(test_generation))
# Out:
# [(['L9', 'L5', 'L3', 'L11', 'L6', 'L2', 'L8', 'L7', 'L4', 'L10', 'L1', 'L9'], 294.28173065185547), (['L2', 'L5', 'L7', 'L4', 'L3', 'L9', 'L6', 'L1', 'L8', 'L10', 'L9', 'L11', 'L2'], 293.47003173828125), (['L6', 'L9', 'L2', 'L7', 'L2', 'L5', 'L4', 'L9', 'L1', 'L8', 'L3', 'L11', 'L10', 'L6'], 358.0016927719116), (['L1', 'L6', 'L8', 'L6', 'L9', 'L5', 'L9', 'L10', 'L11', 'L7', 'L4', 'L2', 'L2', 'L3', 'L1'], 320.40600299835205), (['L1', 'L9', 'L2', 'L9', 'L1', 'L5', 'L3', 'L6', 'L6', 'L2', 'L10', 'L8', 'L4', 'L11', 'L7', 'L1'], 412.35965633392334), (['L2', 'L10', 'L1', 'L7', 'L4', 'L6', 'L5', 'L11', 'L6', 'L9', 'L2', 'L1', 'L3', 'L1', 'L8', 'L9', 'L2'], 392.54063606262207), (['L2', 'L2', 'L4', 'L5', 'L8', 'L6', 'L10', 'L11', 'L1', 'L7', 'L6', 'L1', 'L9', 'L3', 'L9', 'L1', 'L2', 'L2'], 355.9325952529907), (['L4', 'L9', 'L2', 'L1', 'L2', 'L2', 'L1', 'L5', 'L2', 'L10', 'L11', 'L6', 'L3', 'L8', 'L6', 'L1', 'L7', 'L9', 'L4'], 430.73903369903564), (['L2', 'L2', 'L9', 'L6', 'L4', 'L6', 'L8', 'L1', 'L10', 'L9', 'L7', 'L2', 'L3', 'L5', 'L4', 'L11', 'L2', 'L1', 'L1', 'L2'], 406.3711404800415), (['L1', 'L10', 'L2', 'L3', 'L9', 'L4', 'L5', 'L2', 'L1', 'L1', 'L6', 'L6', 'L4', 'L7', 'L8', 'L11', 'L2', 'L2', 'L2', 'L9', 'L1'], 441.9460382461548)]

# %%
def get_breeders_from_generation(guesses, take_best_N=10, take_random_N=5, verbose=False, mutation_rate=0.1):
    """
    This sets up the breeding group for the next generation. You have
    to be very careful how many breeders you take, otherwise your
    population can explode. These two, plus the "number of children per couple"
    in the make_children function must be tuned to avoid exponential growth or decline!
    """
    # First, get the top guesses from last time
    fit_scores = check_fitness(guesses)
    sorted_guesses = sorted(fit_scores, key=lambda x: x[1]) # sorts so lowest is first, which we want
    new_generation = [x[0] for x in sorted_guesses[:take_best_N]]
    best_guess = new_generation[0]
    
    if verbose:
        # If we want to see what the best current guess is!
        print(best_guess)
    
    # Second, get some random ones for genetic diversity
    for _ in range(take_random_N):
        ix = np.random.randint(len(guesses))
        new_generation.append(guesses[ix])
        
    # No mutations here since the order really matters.
    # If we wanted to, we could add a "swapping" mutation,
    # but in practice it doesn't seem to be necessary
    
    np.random.shuffle(new_generation)
    return new_generation, best_guess

def make_child(parent1, parent2):
    """ 
    Take some values from parent 1 and hold them in place, then merge in values
    from parent2, filling in from left to right with cities that aren't already in 
    the child. 
    """
    list_of_ids_for_parent1 = list(np.random.choice(parent1, replace=False, size=len(parent1)//2))
    child = [-99 for _ in parent1]
    
    for ix in range(0, len(list_of_ids_for_parent1)):
        child[ix] = parent1[ix]
    for ix, gene in enumerate(child):
        if gene == -99:
            for gene2 in parent2:
                if gene2 not in child:
                    child[ix] = gene2
                    break
    child[-1] = child[0]
    return child

def make_children(old_generation, children_per_couple=1):
    """
    Pairs parents together, and makes children for each pair. 
    If there are an odd number of parent possibilities, one 
    will be left out. 
    
    Pairing happens by pairing the first and last entries. 
    Then the second and second from last, and so on.
    """
    mid_point = len(old_generation)//2
    next_generation = [] 
    
    for ix, parent in enumerate(old_generation[:mid_point]):
        for _ in range(children_per_couple):
            next_generation.append(make_child(parent, old_generation[-ix-1]))
    return next_generation

# %%
current_generation = create_generation(list(test_locations.keys()),population=500)
print_every_n_generations = 5

for i in range(100):
    if not i % print_every_n_generations:
        print("Generation %i: "%i, end='')
        print(len(current_generation))
        is_verbose = True
    else:
        is_verbose = False
    breeders, best_guess = get_breeders_from_generation(current_generation, 
                                                        take_best_N=250, take_random_N=100, 
                                                        verbose=is_verbose)
    current_generation = make_children(breeders, children_per_couple=3)
# Out:
# Generation 0: 100
# ['L3', 'L10', 'L8', 'L1', 'L5', 'L2', 'L6', 'L11', 'L9', 'L7', 'L4', 'L3']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-d5eb0f49604b> in <module>
#       9     else:
#      10         is_verbose = False
# ---> 11     breeders, best_guess = get_breeders_from_generation(current_generation,
#      12                                                         take_best_N=250, take_random_N=100,
#      13                                                         verbose=is_verbose)
#
# <ipython-input-161-a17b59927ddf> in get_breeders_from_generation(guesses, take_best_N, take_random_N, verbose, mutation_rate)
#       7     """
#       8     # First, get the top guesses from last time
# ----> 9     fit_scores = check_fitness(guesses)
#      10     sorted_guesses = sorted(fit_scores, key=lambda x: x[1]) # sorts so lowest is first, which we want
#      11     new_generation = [x[0] for x in sorted_guesses[:take_best_N]]
#
# <ipython-input-160-d641302599ae> in check_fitness(guesses)
#      17     fitness_indicator = []
#      18     for guess in guesses:
# ---> 19         fitness_indicator.append((guess, fitness_score(guess)))
#      20     return fitness_indicator
#      21
#
# <ipython-input-160-d641302599ae> in fitness_score(guess)
#       7     score = 0
#       8     for ix, point_id in enumerate(guess[:-1]):
# ----> 9         score += travel_time_between_points(coordinates[point_id], coordinates[guess[ix+1]], 11, my_date)
#      10     return score
#      11
#
# KeyError: -99

# %%
def evolve_to_solve(current_generation, max_generations, take_best_N, take_random_N,
                    mutation_rate, children_per_couple, print_every_n_generations, verbose=False):
    """
    Takes in a generation of guesses then evolves them over time using our breeding rules.
    Continue this for "max_generations" times.
    Inputs:
    current_generation: The first generation of guesses
    max_generations: how many generations to complete
    take_best_N: how many of the top performers get selected to breed
    take_random_N: how many random guesses get brought in to keep genetic diversity
    mutation_rate: How often to mutate (currently unused)
    children_per_couple: how many children per breeding pair
    print_every_n_geneartions: how often to print in verbose mode
    verbose: Show printouts of progress
    Returns:
    fitness_tracking: a list of the fitness score at each generations
    best_guess: the best_guess at the end of evolution
    """
    fitness_tracking = []
    for i in range(max_generations):
        if verbose and not i % print_every_n_generations and i > 0:
            print("Generation %i: "%i, end='')
            print(len(current_generation))
            print("Current Best Score: ", fitness_tracking[-1])
            is_verbose = True
        else:
            is_verbose = False
        breeders, best_guess = get_breeders_from_generation(current_generation, 
                                                            take_best_N=take_best_N, take_random_N=take_random_N, 
                                                            verbose=is_verbose, mutation_rate=mutation_rate)
        fitness_tracking.append(fitness_score(best_guess))
        current_generation = make_children(breeders, children_per_couple=children_per_couple)
    
    return fitness_tracking, best_guess

current_generation = create_generation(list(test_locations.keys()),population=500)
fitness_tracking, best_guess = evolve_to_solve(current_generation, 100, 150, 70, 0.5, 3, 5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-d1701da1a9c5> in <module>
#      35
#      36 current_generation = create_generation(list(test_locations.keys()),population=500)
# ---> 37 fitness_tracking, best_guess = evolve_to_solve(current_generation, 100, 150, 70, 0.5, 3, 5, verbose=True)
#
# <ipython-input-163-d1701da1a9c5> in evolve_to_solve(current_generation, max_generations, take_best_N, take_random_N, mutation_rate, children_per_couple, print_every_n_generations, verbose)
#      26         else:
#      27             is_verbose = False
# ---> 28         breeders, best_guess = get_breeders_from_generation(current_generation,
#      29                                                             take_best_N=take_best_N, take_random_N=take_random_N,
#      30                                                             verbose=is_verbose, mutation_rate=mutation_rate)
#
# <ipython-input-161-a17b59927ddf> in get_breeders_from_generation(guesses, take_best_N, take_random_N, verbose, mutation_rate)
#       7     """
#       8     # First, get the top guesses from last time
# ----> 9     fit_scores = check_fitness(guesses)
#      10     sorted_guesses = sorted(fit_scores, key=lambda x: x[1]) # sorts so lowest is first, which we want
#      11     new_generation = [x[0] for x in sorted_guesses[:take_best_N]]
#
# <ipython-input-160-d641302599ae> in check_fitness(guesses)
#      17     fitness_indicator = []
#      18     for guess in guesses:
# ---> 19         fitness_indicator.append((guess, fitness_score(guess)))
#      20     return fitness_indicator
#      21
#
# <ipython-input-160-d641302599ae> in fitness_score(guess)
#       7     score = 0
#       8     for ix, point_id in enumerate(guess[:-1]):
# ----> 9         score += travel_time_between_points(coordinates[point_id], coordinates[guess[ix+1]], 11, my_date)
#      10     return score
#      11
#
# KeyError: -99
